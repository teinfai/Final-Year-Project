# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/Dataset/ana.csv"
path2 = "/content/drive/MyDrive/Dataset/m4t.csv"
path3 = "/content/drive/MyDrive/Dataset/Book1.csv"
dft = pd.read_csv(path2)
dft2 = pd.read_csv(path3)
dataframe = pd.read_csv(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataframe.describe()
# Out:
#        DIAGNOSED_CONDITION  DIABETES_2  ...     Anxiety      Stress
# count           470.000000  470.000000  ...  470.000000  470.000000
# mean              4.031915    3.280851  ...    0.078723    0.106383
# std               2.156223    0.840002  ...    0.269594    0.308656
# min               1.000000    1.000000  ...    0.000000    0.000000
# 25%               2.000000    3.000000  ...    0.000000    0.000000
# 50%               4.000000    4.000000  ...    0.000000    0.000000
# 75%               6.000000    4.000000  ...    0.000000    0.000000
# max               7.000000    4.000000  ...    1.000000    1.000000
#
# [8 rows x 14 columns]

# %%
dataframe[dataframe['Depress'] == 1].count
# Out:
# <bound method DataFrame.count of      DIAGNOSED_CONDITION  DIABETES_2  HYPERTENSION  ...  Depress  Anxiety  Stress
# 0                      1           3             4  ...        1        0       0
# 37                     1           2             4  ...        1        0       0
# 40                     7           2             2  ...        1        0       0
# 41                     7           3             3  ...        1        0       0
# 44                     3           4             4  ...        1        0       0
# 47                     7           2             2  ...        1        0       0
# 50                     4           3             3  ...        1        0       1
# 56                     7           3             3  ...        1        0       0
# 61                     1           3             4  ...        1        0       0
# 64                     7           3             1  ...        1        0       1
# ...

# %%
dataframe[dataframe['Anxiety'] == 1].count
# Out:
# <bound method DataFrame.count of      DIAGNOSED_CONDITION  DIABETES_2  HYPERTENSION  ...  Depress  Anxiety  Stress
# 124                    7           3             3  ...        1        1       1
# 132                    7           2             3  ...        1        1       1
# 142                    2           4             3  ...        1        1       1
# 144                    6           4             2  ...        0        1       1
# 145                    7           3             3  ...        1        1       1
# 156                    7           3             3  ...        1        1       1
# 159                    4           1             3  ...        0        1       0
# 221                    3           4             4  ...        0        1       0
# 297                    7           3             2  ...        1        1       1
# 312                    7           3             3  ...        0        1       1
# ...

# %%
dataframe[dataframe['Stress'] == 1].count
# Out:
# <bound method DataFrame.count of      DIAGNOSED_CONDITION  DIABETES_2  HYPERTENSION  ...  Depress  Anxiety  Stress
# 4                      7           2             2  ...        0        0       1
# 12                     3           4             4  ...        0        0       1
# 50                     4           3             3  ...        1        0       1
# 64                     7           3             1  ...        1        0       1
# 71                     2           4             3  ...        0        0       1
# 116                    1           1             4  ...        0        0       1
# 124                    7           3             3  ...        1        1       1
# 132                    7           2             3  ...        1        1       1
# 133                    7           3             3  ...        1        0       1
# 135                    7           3             3  ...        1        0       1
# ...

# %%
print("Number Of Rows In The Original DataFrame:", len(dataframe))
# Out:
# Number Of Rows In The Original DataFrame: 470

# %%
dp = dataframe['Depress'].value_counts()
axi = dataframe['Anxiety'].value_counts()
sts = dataframe['Stress'].value_counts()

print(f'{dp}')
print("\t")
print(f'{axi}')
print("\t")
print(f'{sts}')
# Out:
# 0    420
# 1     50
# Name: Depress, dtype: int64
#
# 0    433
# 1     37
# Name: Anxiety, dtype: int64
#
# 0    420
# 1     50
# Name: Stress, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import svm
from time import time
from sklearn import metrics
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.colors import ListedColormap

# %%
#sns.pairplot(dataframe)

# %%
test=dataframe.to_numpy()
ob = dft.to_numpy()
ob2 = dft2.to_numpy()
X = test[:, 0:2] 
y = test[:, 12]
x_train, x_test,y_train, y_test = train_test_split(X, y,test_size=0.2, random_state = 0)
print(X.shape)
print(y.shape)
# Out:
# (470, 2)
# (470,)

# %%
#test.shape
#print(f'there is {test.shape} row and column')

# %%
#sns.scatterplot(x=test[:, 0], y=test[:, 4], hue=y)

# %%
X = test[:, 0:1] 
y = test[:, 12]
x_train, x_test,y_train, y_test = train_test_split(X, y,test_size=0.2, random_state = 0)
print(X.shape)
print(y.shape)
# Out:
# (470, 1)
# (470,)

# %%
import numpy
import matplotlib.pyplot as plot
import pandas
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


# Import the dataset


# Split the dataset into the training set and test set
# We're splitting the data in 1/3, so out of 30 rows, 20 rows will go into the training set,
# and 10 rows will go into the testing set.
x_train, x_test,y_train, y_test = train_test_split(X, y,test_size=0.2, random_state = 0)


linearRegressor = LinearRegression()



linearRegressor.fit(x_train, y_train)


y_pred = linearRegressor.predict(x_test)


plot.scatter(x_train, y_train, color = 'red')
plot.plot(x_train, linearRegressor.predict(x_train), color = 'blue')
plot.title('Salary vs Experience (Training set)')
plot.xlabel('Years of Experience')
plot.ylabel('Salary')
plot.show()

# %%
g=sns.displot(data=dataframe, x="GLUCOSE_LEVEL", hue="Depress", multiple="stack")
g.set_axis_labels("GLUCOSE_LEVEL", "Nunmber of Patient")

# %%
g=sns.displot(data=dataframe, x="BP_LEVEL", hue="Depress", multiple="stack")
g.set_axis_labels("BP_LEVEL", "Nunmber of Patient")

# %%
g=sns.displot(data=dataframe, x="TOTAL_CHOLESTEROL_SCORE", hue="Depress", multiple="stack")
g.set_axis_labels("TOTAL_CHOLESTEROL_SCORE", "Nunmber of Patient")

# %%
g=sns.displot(data=dataframe, x="HYPERCHOLESTEROLAEMIA", hue="Depress", multiple="stack")
g.set_axis_labels("HYPERCHOLESTEROLAEMIA", "Nunmber of Patient")

# %%
g=sns.displot(data=dataframe, x="GLUCOSE_LEVEL", hue="Anxiety", multiple="stack")
g.set_axis_labels("GLUCOSE_LEVEL", "Nunmber of Patient")

# %%
g=sns.displot(data=dataframe, x="BP_LEVEL", hue="Anxiety", multiple="stack")
g.set_axis_labels("BP_LEVEL", "Nunmber of Patient")

# %%
g=sns.displot(data=dataframe, x="TOTAL_CHOLESTEROL_SCORE", hue="Anxiety", multiple="stack")
g.set_axis_labels("TOTAL_CHOLESTEROL_SCORE", "Nunmber of Patient")

# %%
g=sns.displot(data=dataframe, x="HYPERCHOLESTEROLAEMIA", hue="Anxiety", multiple="stack")
g.set_axis_labels("HYPERCHOLESTEROLAEMIA", "Nunmber of Patient")

# %%
g=sns.displot(data=dataframe, x="GLUCOSE_LEVEL", hue="Stress", multiple="stack")
g.set_axis_labels("GLUCOSE_LEVEL", "Nunmber of Patient")

# %%
g=sns.displot(data=dataframe, x="BP_LEVEL", hue="Stress", multiple="stack")
g.set_axis_labels("BP_LEVEL", "Nunmber of Patient")

# %%
g=sns.displot(data=dataframe, x="TOTAL_CHOLESTEROL_SCORE", hue="Stress", multiple="stack")
g.set_axis_labels("TOTAL_CHOLESTEROL_SCORE", "Nunmber of Patient")

# %%
g=sns.displot(data=dataframe, x="HYPERCHOLESTEROLAEMIA", hue="Stress", multiple="stack")
g.set_axis_labels("HYPERCHOLESTEROLAEMIA", "Nunmber of Patient")

# %%
g = sns.FacetGrid(dataframe, col='Stress')
g = g.map(sns.kdeplot, 'TOTAL_CHOLESTEROL_SCORE')
g.set_axis_labels("HYPERCHOLESTEROLAEMIA", "Stress")

#g = sns.FacetGrid(dataframe, col='Stress')
#g = g.map(sns.kdeplot, 'HYPERCHOLESTEROLAEMIA_OCCURS')

# %%
#g=sns.displot(data=dataframe, x="HYPERCHOLESTEROLAEMIA", hue="Stress", multiple="stack")
#g.set_axis_labels("HYPERCHOLESTEROLAEMIA", "Nunmber of Patient")

# %%
sns.jointplot(
    data=dataframe,
    x="DIAGNOSED_CONDITION", y="DIABETES_2", hue=y,
    kind="kde"
)

# %%
sns.jointplot(data=dataframe, x="DIAGNOSED_CONDITION", y="DIABETES_2", hue=y)

# %%
sns.relplot(data=dataframe, x="DIAGNOSED_CONDITION", y="DIABETES_2", hue=y)

# %%
y = test[:, 11]
g=sns.displot(data=dataframe, x="Depress", hue=y)
g.set_axis_labels("Depress", "Number of patient")

# %%
y = test[:, 12]
g=sns.displot(data=dataframe, x="Anxiety", hue=y)
g.set_axis_labels("Anxiety", "Number of patient")

# %%
y = test[:, 13]
g=sns.displot(data=dataframe, x="Stress", hue=y)
g.set_axis_labels("Stress", "Number of patient")

# %%
sns.displot(dataframe, x="DIAGNOSED_CONDITION", y="DIABETES_2")

# %%
sns.displot(dataframe, x="DIAGNOSED_CONDITION", y="DIABETES_2", hue=y)

# %%
#g = sns.PairGrid(dataframe)
#g.map_upper(sns.histplot)
#g.map_lower(sns.kdeplot, fill=True)
#g.map_diag(sns.histplot, kde=True)

# %%
sns.displot(dataframe, x="DIAGNOSED_CONDITION", hue=y, multiple="stack")

# %%
sns.displot(dataframe, x="DIAGNOSED_CONDITION", hue=y, element="step")

# %%
sns.displot(dataframe, x="DIAGNOSED_CONDITION", kind="kde", bw_adjust=.25)
